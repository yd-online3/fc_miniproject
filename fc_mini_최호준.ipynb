# %%
plt.rc("font", family = "Malgun Gothic")
sns.set(font="Malgun Gothic", 
rc={"axes.unicode_minus":False}, style='darkgrid')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'C:/Users/hojun/Documents/dev/mini_project/파이널프로젝트_RAW_210329_210926.xlsx'
df = pd.read_excel(url)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105419 entries, 0 to 105418
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id                      105419 non-null  int64
#  1   customer_id             105416 non-null  float64
#  2   course_id               100212 non-null  float64
#  3   type                    105419 non-null  object
#  4   state                   105419 non-null  object
#  5   course_title            105403 non-null  object
#  6   category_title          105395 non-null  object
#  7   format                  105403 non-null  object
#  8   completed_at            105419 non-null  datetime64[ns]
#  9   transaction_amount      105419 non-null  int64
#  10  coupon_title            31817 non-null   object
#  11  coupon_discount_amount  31817 non-null   float64
#  12  sale_price              104291 non-null  float64
#  13  tax_free_amount         104291 non-null  float64
#  14  pg                      90344 non-null   object
#  15  method                  92323 non-null   object
#  16  subcategory_title       85590 non-null   object
#  17  marketing_start_at      87440 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(5), int64(2), object(9)
# memory usage: 14.5+ MB

# %%
df['course_title'].unique()
# Out:
# array(['올인원 패키지 : 알고리즘 기술면접 완전 정복', '초격차 패키지 : 한번에 끝내는 영상 촬영과 편집',
#        '시크릿코드 : 프론트엔드 실무 완성편', ..., '(B2B) 그린오션스 온라인 구독 올 플랜 - 비대면바우처',
#        '(B2B) 디캠프 패밀리사 온라인 구독 올 플랜 (9월)',
#        '(B2B) (주)오디 온라인 구독 올 플랜 - 비대면바우처'], dtype=object)

# %%
df['category_title'].unique()
# Out:
# array(['프로그래밍', '영상/3D', '업무 생산성', '크리에이티브', '부동산/금융', '데이터사이언스', '디자인',
#        '마케팅', '교육', '투자/재테크', nan, '관리', '데이터 사이언스', '비즈니스', '지식콘텐츠',
#        '일러스트', '파이낸스'], dtype=object)

# %%
df['category_title'].unique()

# %%
df['format'].unique()
# Out:
# array(['올인원', '스쿨 온라인', '온라인 완주반', 'RED', 'B2B 온라인', '캠프', '스쿨', nan,
#        'B2B', '이벤트', '하루10분컷', '아카이브', '관리', '온라인', 'MBA', '콜로소', 'B2G'],
#       dtype=object)

# %%
df['coupon_title'].nunique()
# Out:
# 494

# %%
df['coupon_discount_amount'].nunique()
# Out:
# 773

# %%
df['pg'].unique()
# Out:
# array([nan, 'INICIS', 'KAKAO', 'CHAI', 'PAYCO', 'NAVER'], dtype=object)

# %%
df['method'].unique()
# Out:
# array(['VBANK', 'CARD', 'TRANS', 'PROMOTION', 'TRANSFER', 'ONSITE',
#        'B2B_CONTRACT', nan, 'POINT', 'VOUCHER'], dtype=object)

# %%
df['subcategory_title'].unique()
# Out:
# array(['개발자 커리어', '영상 편집', nan, 'PPT/보고서', '금융/투자 실무', '프론트엔드 개발',
#        'DevOps', 'UX/UI', '머신러닝', '모션그래픽', '딥러닝/인공지능', '글쓰기/카피라이팅',
#        '디지털마케팅', '엑셀/VBA', '데이터분석', '디자인툴', '모바일앱', '업무자동화', 'SNS마케팅',
#        '게임', '회계/재무/세무', '부동산 개발', '시각디자인', '백엔드 개발', '데이터마케팅', '일러스트',
#        '부동산 투자', '코딩 입문', '커뮤니케이션', '리더십', '주식 투자', '게임 그래픽', '데이터엔지니어링',
#        'VFX'], dtype=object)

# %%
df['marketing_start_at'].unique()

# %%
df['sale_price'].max()
# Out:
# 90940000.0

# %%
df['customer_id'].nunique()
# Out:
# 53753

# %%
df
# Out:
#              id  customer_id  course_id     type      state  \
# 0        970634     504760.0   201435.0    ORDER  CANCELLED
# 1        970650     432862.0   203178.0    ORDER  CANCELLED
# 2        970657      72297.0   204246.0  PAYMENT  COMPLETED
# 3        970656      72297.0   204246.0    ORDER  CANCELLED
# 4        970658     478028.0   201797.0  PAYMENT  COMPLETED
# ...         ...          ...        ...      ...        ...
# 105414  1364995     640697.0   205365.0  PAYMENT  CANCELLED
# 105415  1364998     670896.0   204159.0  PAYMENT  CANCELLED
# 105416  1364996     640697.0   205365.0  PAYMENT  COMPLETED
# 105417  1365005     670896.0   204159.0  PAYMENT  CANCELLED
# 105418  1365007     610626.0   206720.0  PAYMENT  COMPLETED
#
#                            course_title category_title  format  \
# 0             올인원 패키지 : 알고리즘 기술면접 완전 정복          프로그래밍     올인원
# 1           초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D     올인원
# 2                  시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인
# 3                  시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인
# 4         올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성     올인원
# ...                                 ...            ...     ...
# 105414  초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기          영상/3D     올인원
# 105415              부동산 디벨로퍼 아카데미 : 인허가         부동산/금융     올인원
# 105416  초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기          영상/3D     올인원
# 105417              부동산 디벨로퍼 아카데미 : 인허가         부동산/금융     올인원
# 105418               용호수의 돈 버는 실전 영상 제작          영상/3D     올인원
#
#               completed_at  transaction_amount               coupon_title  \
# 0      2021-03-28 15:00:11               90500                        NaN
# 1      2021-03-28 15:16:53               96000                        NaN
# 2      2021-03-28 15:21:43              171810      [10% 할인] 시크릿코드 실무 완성편
# 3      2021-03-28 15:21:43              171810                        NaN
# 4      2021-03-28 15:21:54               97500   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# ...                    ...                 ...                        ...
# 105414 2021-09-25 14:10:42               96000  [WELCOME] 온라인 강의 2만원 할인쿠폰
# 105415 2021-09-25 14:16:33              189000                        NaN
# 105416 2021-09-25 14:17:41               96000  [WELCOME] 온라인 강의 2만원 할인쿠폰
# 105417 2021-09-25 14:19:56              189000                        NaN
# 105418 2021-09-25 14:25:47              139000  [WELCOME] 온라인 강의 3만원 할인쿠폰
#
#         coupon_discount_amount  sale_price  tax_free_amount      pg method  \
# 0                          NaN    110500.0         110500.0     NaN  VBANK
# 1                          NaN    116000.0         116000.0     NaN   CARD
# 2                      19090.0    190900.0         190900.0     NaN   CARD
# 3                          NaN    190900.0         190900.0     NaN   CARD
# 4                      20000.0    117500.0         117500.0     NaN   CARD
# ...                        ...         ...              ...     ...    ...
# 105414                 20000.0    116000.0         116000.0  INICIS  TRANS
# 105415                     NaN    189000.0         189000.0  INICIS   CARD
# 105416                 20000.0    116000.0         116000.0  INICIS  VBANK
# 105417                     NaN    189000.0         189000.0  INICIS   CARD
# 105418                 30000.0    169000.0         169000.0   NAVER  POINT
#
#        subcategory_title marketing_start_at
# 0                개발자 커리어                NaT
# 1                  영상 편집         2020-12-02
# 2                    NaN         2021-03-04
# 3                    NaN         2021-03-04
# 4                PPT/보고서         2019-11-14
# ...                  ...                ...
# 105414             영상 편집         2021-06-15
# 105415            부동산 개발         2021-02-10
# 105416             영상 편집         2021-06-15
# 105417            부동산 개발         2021-02-10
# 105418             영상 편집         2021-08-17
#
# [105419 rows x 18 columns]

# %%
sns.histplot(data= df,  x='state')
# Out:
# <AxesSubplot:xlabel='state', ylabel='Count'>

# %%
plt.figure(figsize=(20,8))
sns.histplot(data= df,  x='subcategory_title')
plt.xticks(rotation=-45, fontsize=10)
plt.show()

# %%
plt.figure(figsize=(20,8))
sns.histplot(data= df,  x='method')
plt.xticks(rotation=-45, fontsize=10)
plt.show()

# %%
plt.figure(figsize=(20,8))
sns.histplot(data= df,  x='marketing_start_at')
plt.xticks(rotation=-45, fontsize=10)
plt.show()

# %%
plt.figure(figsize=(20,8))
sns.histplot(data= df,  x='coupon_title')
plt.xticks(rotation=-45, fontsize=10)
plt.show()
# Out:
# c:\Users\hojun\miniforge3\envs\fastcampus\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df['course_title'] + df['category_title']
# Out:
# 0               올인원 패키지 : 알고리즘 기술면접 완전 정복프로그래밍
# 1             초격차 패키지 : 한번에 끝내는 영상 촬영과 편집영상/3D
# 2                    시크릿코드 : 프론트엔드 실무 완성편프로그래밍
# 3                    시크릿코드 : 프론트엔드 실무 완성편프로그래밍
# 4          올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX업무 생산성
#                           ...
# 105414    초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기영상/3D
# 105415               부동산 디벨로퍼 아카데미 : 인허가부동산/금융
# 105416    초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기영상/3D
# 105417               부동산 디벨로퍼 아카데미 : 인허가부동산/금융
# 105418                 용호수의 돈 버는 실전 영상 제작영상/3D
# Length: 105419, dtype: object

# %%
df[df['method']]
# Out:
# 0         VBANK
# 1          CARD
# 2          CARD
# 3          CARD
# 4          CARD
#           ...
# 105414    TRANS
# 105415     CARD
# 105416    VBANK
# 105417     CARD
# 105418    POINT
# Name: method, Length: 105419, dtype: object

# %%
df['pg'] + df['method']
# Out:
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#              ...
# 105414    INICISTRANS
# 105415     INICISCARD
# 105416    INICISVBANK
# 105417     INICISCARD
# 105418     NAVERPOINT
# Length: 105419, dtype: object

# %%
payment_data = df
payment_data['pg'] = df['pg'].fillna('PG')

# %%
payment_data[payment_data['payment_data'].isna()]
# Out:
#              id  customer_id  course_id     type      state  \
# 21515   1035779     147114.0   203527.0    ORDER  CANCELLED
# 21516   1035784     167967.0   203532.0    ORDER  CANCELLED
# 21517   1035786     147114.0   203527.0    ORDER  CANCELLED
# 21518   1035778     485705.0   203787.0    ORDER  CANCELLED
# 21521   1035794     167967.0   203532.0    ORDER  CANCELLED
# ...         ...          ...        ...      ...        ...
# 105350  1364698     646968.0   205879.0  PAYMENT  CANCELLED
# 105351  1364699     646968.0   206888.0  PAYMENT  CANCELLED
# 105390  1364858      37866.0   205707.0  PAYMENT  CANCELLED
# 105396  1364879     623392.0   206060.0  PAYMENT  CANCELLED
# 105407  1364951      87331.0   205743.0  PAYMENT  CANCELLED
#
#                                              course_title category_title  \
# 21515   올인원 패키지 : 김민태의 프론트엔드 아카데미 : 제 1강 JavaScript & ...          프로그래밍
# 21516               연습문제 패키지 : 퀴즈처럼 풀면서 배우는 파이썬 딥러닝 300제+        데이터사이언스
# 21517   올인원 패키지 : 김민태의 프론트엔드 아카데미 : 제 1강 JavaScript & ...          프로그래밍
# 21518                             초격차 패키지 : 한번에 끝내는 디자인 툴            디자인
# 21521               연습문제 패키지 : 퀴즈처럼 풀면서 배우는 파이썬 딥러닝 300제+        데이터사이언스
# ...                                                   ...            ...
# 105350       올인원 패키지 : 누적 다운로드 120만+ 1인 개발자와 함께하는 앱 개발 입문          프로그래밍
# 105351  올인원 패키지 : 글로벌 1위 Salesforce 디자인 디렉터의 B2B SaaS ...            디자인
# 105390     올인원 패키지 : 15명의 전문 애널리스트에게 배우는 산업&매크로 분석과 투자 전략         투자/재테크
# 105396           초격차 패키지 : 한 번에 끝내는 컴퓨터 공학 전공필수 & 인공지능 심화          프로그래밍
# 105407                           초격차 패키지 : 한번에 끝내는 재무세무회계         부동산/금융
#
#        format        completed_at  transaction_amount  \
# 21515     올인원 2021-04-28 14:01:25               99000
# 21516     올인원 2021-04-28 14:01:56               92000
# 21517     올인원 2021-04-28 14:02:27               99000
# 21518     올인원 2021-04-28 14:02:53               32000
# 21521     올인원 2021-04-28 14:03:32               92000
# ...       ...                 ...                 ...
# 105350    올인원 2021-09-25 02:29:26              149000
# 105351    올인원 2021-09-25 02:30:51              149000
# 105390    올인원 2021-09-25 11:17:16              339000
# 105396    올인원 2021-09-25 11:38:53              173000
# 105407    올인원 2021-09-25 13:10:15              285000
#
#                      coupon_title  coupon_discount_amount  sale_price  \
# 21515                         NaN                     NaN     99000.0
# 21516                         NaN                     NaN     92000.0
# 21517                         NaN                     NaN     99000.0
# 21518           4월 1+1 페이백 이벤트 쿠폰                140000.0    172000.0
# 21521                         NaN                     NaN     92000.0
# ...                           ...                     ...         ...
# 105350  [WELCOME] 온라인 강의 3만원 할인쿠폰                 30000.0    179000.0
# 105351  [WELCOME] 온라인 강의 2만원 할인쿠폰                 20000.0    169000.0
# 105390                        NaN                     NaN    339000.0
# 105396  [WELCOME] 온라인 강의 3만원 할인쿠폰                 30000.0    203000.0
# 105407                        NaN                     NaN    285000.0
#
#         tax_free_amount     pg method subcategory_title  marketing_start_at  \
# 21515           99000.0  KAKAO    NaN          프론트엔드 개발 2021-04-07 00:00:00
# 21516           92000.0   CHAI    NaN          딥러닝/인공지능 2021-02-22 00:00:00
# 21517           99000.0  PAYCO    NaN          프론트엔드 개발 2021-04-07 00:00:00
# 21518          172000.0  KAKAO    NaN              디자인툴 2020-12-24 11:00:00
# 21521           92000.0  PAYCO    NaN          딥러닝/인공지능 2021-02-22 00:00:00
# ...                 ...    ...    ...               ...                 ...
# 105350         179000.0  NAVER    NaN              모바일앱 2021-07-02 00:00:00
# 105351         169000.0  KAKAO    NaN             UX/UI 2021-08-23 00:00:00
# 105390         339000.0  KAKAO    NaN             주식 투자 2021-06-23 00:00:00
# 105396         203000.0  KAKAO    NaN           개발자 커리어 2021-07-16 00:00:00
# 105407         285000.0  NAVER    NaN          회계/재무/세무 2021-09-13 00:00:00
#
#        payment_data
# 21515           NaN
# 21516           NaN
# 21517           NaN
# 21518           NaN
# 21521           NaN
# ...             ...
# 105350          NaN
# 105351          NaN
# 105390          NaN
# 105396          NaN
# 105407          NaN
#
# [13096 rows x 19 columns]

# %%
df[df['method'].isna()]['pg'].unique()
# Out:
# array(['KAKAO', 'CHAI', 'PAYCO', 'NAVER'], dtype=object)

# %%
df[df['method'].isna()]['state'].unique()
# Out:
# array(['CANCELLED', 'REQUESTED', 'COMPLETED'], dtype=object)

# %%
df[df['pg']=='NAVER']
# Out:
#              id  customer_id  course_id     type      state  \
# 21569   1035969     427975.0   202929.0    ORDER  CANCELLED
# 21572   1035889     152972.0   203720.0    ORDER  CANCELLED
# 21576   1035985     427975.0   202929.0    ORDER  CANCELLED
# 21592   1036049     427975.0   203720.0    ORDER  CANCELLED
# 21723   1036381     496508.0   201520.0    ORDER  CANCELLED
# ...         ...          ...        ...      ...        ...
# 105371  1364756     490127.0   204670.0  PAYMENT  COMPLETED
# 105373  1364763     670735.0   201998.0  PAYMENT  COMPLETED
# 105389  1364855     503113.0   205879.0  PAYMENT  COMPLETED
# 105407  1364951      87331.0   205743.0  PAYMENT  CANCELLED
# 105418  1365007     610626.0   206720.0  PAYMENT  COMPLETED
#
#                                         course_title category_title format  \
# 21569                       The RED : 데이터 사이언티스트 하용호        데이터사이언스    RED
# 21572                    초격차 패키지 : 한 번에 끝내는 프론트엔드 개발          프로그래밍    올인원
# 21576                       The RED : 데이터 사이언티스트 하용호        데이터사이언스    RED
# 21592                    초격차 패키지 : 한 번에 끝내는 프론트엔드 개발          프로그래밍    올인원
# 21723                올인원 패키지 : AWS/Docker 클라우드 서버 구축          프로그래밍    올인원
# ...                                              ...            ...    ...
# 105371        The RED : 김영하 작가의 내 안의 숨은 이야기를 찾아 쓰는 법            마케팅    RED
# 105373                            올인원 패키지 : iOS 앱 개발          프로그래밍    올인원
# 105389  올인원 패키지 : 누적 다운로드 120만+ 1인 개발자와 함께하는 앱 개발 입문          프로그래밍    올인원
# 105407                      초격차 패키지 : 한번에 끝내는 재무세무회계         부동산/금융    올인원
# 105418                            용호수의 돈 버는 실전 영상 제작          영상/3D    올인원
#
#               completed_at  transaction_amount               coupon_title  \
# 21569  2021-04-28 14:41:10              198000                        NaN
# 21572  2021-04-28 14:41:45              113000                        NaN
# 21576  2021-04-28 14:44:54              198000                        NaN
# 21592  2021-04-28 15:03:47              113000                        NaN
# 21723  2021-04-28 16:39:03              108500                        NaN
# ...                    ...                 ...                        ...
# 105371 2021-09-25 08:09:48              171000                        NaN
# 105373 2021-09-25 08:28:36              155000    [미래투자금] 온라인 강의 2만원 할인쿠폰
# 105389 2021-09-25 11:13:49              179000                        NaN
# 105407 2021-09-25 13:10:15              285000                        NaN
# 105418 2021-09-25 14:25:47              139000  [WELCOME] 온라인 강의 3만원 할인쿠폰
#
#         coupon_discount_amount  sale_price  tax_free_amount     pg method  \
# 21569                      NaN    198000.0         198000.0  NAVER    NaN
# 21572                      NaN    113000.0         113000.0  NAVER    NaN
# 21576                      NaN    198000.0         198000.0  NAVER    NaN
# 21592                      NaN    113000.0         113000.0  NAVER    NaN
# 21723                      NaN    108500.0         108500.0  NAVER    NaN
# ...                        ...         ...              ...    ...    ...
# 105371                     NaN    171000.0         171000.0  NAVER   CARD
# 105373                 20000.0    175000.0         175000.0  NAVER   CARD
# 105389                     NaN    179000.0         179000.0  NAVER  POINT
# 105407                     NaN    285000.0         285000.0  NAVER    NaN
# 105418                 30000.0    169000.0         169000.0  NAVER  POINT
#
#        subcategory_title  marketing_start_at
# 21569              데이터분석 2020-08-26 00:00:00
# 21572           프론트엔드 개발 2021-02-02 00:00:00
# 21576              데이터분석 2020-08-26 00:00:00
# 21592           프론트엔드 개발 2021-02-02 00:00:00
# 21723             DevOps                 NaT
# ...                  ...                 ...
# 105371         글쓰기/카피라이팅 2021-06-18 17:00:00
# 105373              모바일앱 2020-01-14 00:00:00
# 105389              모바일앱 2021-07-02 00:00:00
# 105407          회계/재무/세무 2021-09-13 00:00:00
# 105418             영상 편집 2021-08-17 00:00:00
#
# [8045 rows x 18 columns]

# %%
payment_data['method'] = df['method'].fillna('')
payment_data['payment_data']
# Out:
# 0             PG VBANK
# 1              PG CARD
# 2              PG CARD
# 3              PG CARD
# 4              PG CARD
#               ...
# 105414    INICIS TRANS
# 105415     INICIS CARD
# 105416    INICIS VBANK
# 105417     INICIS CARD
# 105418     NAVER POINT
# Name: payment_data, Length: 105419, dtype: object

# %%
payment_data['payment_data']= df['pg'] + ' ' + df['method']
payment_data['payment_data']
# Out:
# 0             PG VBANK
# 1              PG CARD
# 2              PG CARD
# 3              PG CARD
# 4              PG CARD
#               ...
# 105414    INICIS TRANS
# 105415     INICIS CARD
# 105416    INICIS VBANK
# 105417     INICIS CARD
# 105418     NAVER POINT
# Name: payment_data, Length: 105419, dtype: object

# %%
payment_data['payment_data'].isna().count()
# Out:
# 105419

# %%
payment_data = payment_data.drop(columns=['pg', 'method'])
payment_data
# Out:
#              id  customer_id  course_id     type      state  \
# 0        970634     504760.0   201435.0    ORDER  CANCELLED
# 1        970650     432862.0   203178.0    ORDER  CANCELLED
# 2        970657      72297.0   204246.0  PAYMENT  COMPLETED
# 3        970656      72297.0   204246.0    ORDER  CANCELLED
# 4        970658     478028.0   201797.0  PAYMENT  COMPLETED
# ...         ...          ...        ...      ...        ...
# 105414  1364995     640697.0   205365.0  PAYMENT  CANCELLED
# 105415  1364998     670896.0   204159.0  PAYMENT  CANCELLED
# 105416  1364996     640697.0   205365.0  PAYMENT  COMPLETED
# 105417  1365005     670896.0   204159.0  PAYMENT  CANCELLED
# 105418  1365007     610626.0   206720.0  PAYMENT  COMPLETED
#
#                            course_title category_title  format  \
# 0             올인원 패키지 : 알고리즘 기술면접 완전 정복          프로그래밍     올인원
# 1           초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D     올인원
# 2                  시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인
# 3                  시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인
# 4         올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성     올인원
# ...                                 ...            ...     ...
# 105414  초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기          영상/3D     올인원
# 105415              부동산 디벨로퍼 아카데미 : 인허가         부동산/금융     올인원
# 105416  초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기          영상/3D     올인원
# 105417              부동산 디벨로퍼 아카데미 : 인허가         부동산/금융     올인원
# 105418               용호수의 돈 버는 실전 영상 제작          영상/3D     올인원
#
#               completed_at  transaction_amount               coupon_title  \
# 0      2021-03-28 15:00:11               90500                        NaN
# 1      2021-03-28 15:16:53               96000                        NaN
# 2      2021-03-28 15:21:43              171810      [10% 할인] 시크릿코드 실무 완성편
# 3      2021-03-28 15:21:43              171810                        NaN
# 4      2021-03-28 15:21:54               97500   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# ...                    ...                 ...                        ...
# 105414 2021-09-25 14:10:42               96000  [WELCOME] 온라인 강의 2만원 할인쿠폰
# 105415 2021-09-25 14:16:33              189000                        NaN
# 105416 2021-09-25 14:17:41               96000  [WELCOME] 온라인 강의 2만원 할인쿠폰
# 105417 2021-09-25 14:19:56              189000                        NaN
# 105418 2021-09-25 14:25:47              139000  [WELCOME] 온라인 강의 3만원 할인쿠폰
#
#         coupon_discount_amount  sale_price  tax_free_amount subcategory_title  \
# 0                          NaN    110500.0         110500.0           개발자 커리어
# 1                          NaN    116000.0         116000.0             영상 편집
# 2                      19090.0    190900.0         190900.0               NaN
# 3                          NaN    190900.0         190900.0               NaN
# 4                      20000.0    117500.0         117500.0           PPT/보고서
# ...                        ...         ...              ...               ...
# 105414                 20000.0    116000.0         116000.0             영상 편집
# 105415                     NaN    189000.0         189000.0            부동산 개발
# 105416                 20000.0    116000.0         116000.0             영상 편집
# 105417                     NaN    189000.0         189000.0            부동산 개발
# 105418                 30000.0    169000.0         169000.0             영상 편집
#
#        marketing_start_at  payment_data
# 0                     NaT      PG VBANK
# 1              2020-12-02       PG CARD
# 2              2021-03-04       PG CARD
# 3              2021-03-04       PG CARD
# 4              2019-11-14       PG CARD
# ...                   ...           ...
# 105414         2021-06-15  INICIS TRANS
# 105415         2021-02-10   INICIS CARD
# 105416         2021-06-15  INICIS VBANK
# 105417         2021-02-10   INICIS CARD
# 105418         2021-08-17   NAVER POINT
#
# [105419 rows x 17 columns]

# %%
plt.figure(figsize=(20,8))
sns.histplot(data= df,  x='payment_data')
plt.xticks(rotation=-90, fontsize=10)
plt.show()

# %% [markdown]
# ### 결제수단 열 병합
